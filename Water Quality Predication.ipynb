# %% [markdown]
# # Water Quality Predication

# %% [markdown]
# ## Week 1 Project Submission

# %%
# Import necessary libraries
#use to data manipulation
import pandas as pd
# for numerical python - linear algebra
import numpy as np 
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
# to load a CSV file into a DataFrame in Python 
df = pd.read_csv('afa2e701598d20110228.csv', sep=';')
df
# Out:
#       id        date    NH4  BSK5  Suspended     O2    NO3    NO2     SO4  \
# 0      1  17.02.2000  0.330  2.77       12.0  12.30   9.50  0.057  154.00
# 1      1  11.05.2000  0.044  3.00       51.6  14.61  17.75  0.034  352.00
# 2      1  11.09.2000  0.032  2.10       24.5   9.87  13.80  0.173  416.00
# 3      1  13.12.2000  0.170  2.23       35.6  12.40  17.13  0.099  275.20
# 4      1  02.03.2001  0.000  3.03       48.8  14.69  10.00  0.065  281.60
# ...   ..         ...    ...   ...        ...    ...    ...    ...     ...
# 2856  22  06.10.2020  0.046  2.69        3.6   8.28   3.80  0.038  160.00
# 2857  22  27.10.2020  0.000  1.52        0.5  11.26   0.56  0.031  147.20
# 2858  22  03.12.2020  0.034  0.29        0.8  11.09   2.58  0.042  209.92
# 2859  22  12.01.2021  0.000  2.10        0.0  14.31   3.94  0.034  121.60
# 2860  22  10.02.2021  0.000  1.78        0.0  14.30   6.30  0.033  134.40
#
#         PO4       CL
# 0     0.454   289.50
# 1     0.090  1792.00
# ...

# %%
# dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2861 non-null   int64
#  1   date       2861 non-null   object
#  2   NH4        2858 non-null   float64
#  3   BSK5       2860 non-null   float64
#  4   Suspended  2845 non-null   float64
#  5   O2         2858 non-null   float64
#  6   NO3        2860 non-null   float64
#  7   NO2        2858 non-null   float64
#  8   SO4        2812 non-null   float64
#  9   PO4        2833 non-null   float64
#  10  CL         2812 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 246.0+ KB

# %%
# to know about rows and cols
df.shape
# Out:
# (2861, 11)

# %%
#  for Statistics of the data
df.describe().T
# Out:
#             count       mean         std   min      25%     50%       75%  \
# id         2861.0  12.397064    6.084226  1.00   8.0000  14.000  16.00000
# NH4        2858.0   0.758734    2.486247  0.00   0.0800   0.220   0.50000
# BSK5       2860.0   4.316182    2.973997  0.00   2.1600   3.800   5.80000
# Suspended  2845.0  12.931905   16.543097  0.00   6.0000  10.000  15.00000
# O2         2858.0   9.508902    4.428260  0.00   7.0925   8.995  11.52000
# NO3        2860.0   4.316846    6.881188  0.00   1.3900   2.800   5.58250
# NO2        2858.0   0.246128    2.182777  0.00   0.0300   0.059   0.12575
# SO4        2812.0  59.362313   96.582641  0.00  27.0525  37.800  64.64000
# PO4        2833.0   0.418626    0.771326  0.00   0.1300   0.270   0.47000
# CL         2812.0  93.731991  394.512184  0.02  26.8000  33.900  45.60750
#
#                 max
# id           22.000
# NH4          39.427
# BSK5         50.900
# Suspended   595.000
# O2           90.000
# NO3         133.400
# ...

# %%
# to check how many duplicate rows exist in a DataFrame
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# identify missing values in each column
df.isnull().sum()
# Out:
# id            0
# date          0
# NH4           3
# BSK5          1
# Suspended    16
# O2            3
# NO3           1
# NO2           3
# SO4          49
# PO4          28
# CL           49
# dtype: int64

# %%
# date is in object - date format
df['date'] = pd.to_datetime(df['date'], format='%d.%m.%Y')
df
# Out:
#       id       date    NH4  BSK5  Suspended     O2    NO3    NO2     SO4  \
# 0      1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.00
# 1      1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.00
# 2      1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.00
# 3      1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.20
# 4      1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.60
# ...   ..        ...    ...   ...        ...    ...    ...    ...     ...
# 2856  22 2020-10-06  0.046  2.69        3.6   8.28   3.80  0.038  160.00
# 2857  22 2020-10-27  0.000  1.52        0.5  11.26   0.56  0.031  147.20
# 2858  22 2020-12-03  0.034  0.29        0.8  11.09   2.58  0.042  209.92
# 2859  22 2021-01-12  0.000  2.10        0.0  14.31   3.94  0.034  121.60
# 2860  22 2021-02-10  0.000  1.78        0.0  14.30   6.30  0.033  134.40
#
#         PO4       CL
# 0     0.454   289.50
# 1     0.090  1792.00
# 2     0.200  2509.00
# ...

# %%
#  sort the dataframe with refer to specific column .
df = df.sort_values(by=['id', 'date'])
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL
# 0   289.5
# 1  1792.0
# 2  2509.0
# 3  1264.0
# 4  1462.0

# %%
#xtract the year and month from the column 
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL  year  month
# 0   289.5  2000      2
# 1  1792.0  2000      5
# 2  2509.0  2000      9
# 3  1264.0  2000     12
# 4  1462.0  2001      3

# %%
df.columns
# Out:
# Index(['id', 'date', 'NH4', 'BSK5', 'Suspended', 'O2', 'NO3', 'NO2', 'SO4',
#        'PO4', 'CL', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# ## Week2 Project Submission

# %% [markdown]
# ### Random Forset Regression Model

# %%
pollutants = ['O2', 'NO3', 'NO2', 'SO4', 'PO4', 'CL']

# %%
# drop the missing values using dropna()
df = df.dropna(subset=pollutants)
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL  year  month
# 0   289.5  2000      2
# 1  1792.0  2000      5
# 2  2509.0  2000      9
# 3  1264.0  2000     12
# 4  1462.0  2001      3

# %%
#  Checking for Null Values 
df.isnull().sum()
# Out:
# id           0
# date         0
# NH4          2
# BSK5         0
# Suspended    2
# O2           0
# NO3          0
# NO2          0
# SO4          0
# PO4          0
# CL           0
# year         0
# month        0
# dtype: int64

# %%
# Feature and target selection where Feature are independent variable and Target are dependent variable
X = df[['id', 'year']]
y = df[pollutants]
# Here x is  Independent variables and y is dependent variable

# %%
#  Encoding the Categorical Variable - Converts id  into one-hot encoded columns
X_encoded = pd.get_dummies(X, columns=['id'], drop_first=True)

# %%
# Splitting the Data into Train and Test 
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Model Training using MultiOutput Regressor with Random forest Regressor
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
#  Model Prediction
y_pred = model.predict(X_test)

# %%
# Model Evaluation
print("Model Performance on the Test Data:")
for i, pollutant in enumerate(pollutants):
    print(f'{pollutant}:')
    print('   MSE:', mean_squared_error(y_test.iloc[:, i], y_pred[:, i]))
    print('   R2:', r2_score(y_test.iloc[:, i], y_pred[:, i]))
    print()
# Out:
# Model Performance on the Test Data:
# O2:
#    MSE: 22.21825046040189
#    R2: -0.01674257045728833
#
# NO3:
#    MSE: 18.153106746365886
#    R2: 0.5162032171220556
#
# NO2:
#    MSE: 10.607352172601502
#    R2: -78.42066512350873
#
# SO4:
#    MSE: 2412.139350033052
#    R2: 0.4118345603876148
#
# PO4:
#    MSE: 0.38496938017964155
#    R2: 0.3221189891402043
#
# CL:
#    MSE: 34882.81433245622
#    R2: 0.7357918194149974

# %%
# Doing Prediction by taking an Example like taking specific station and year.
station_id = '19'
year_input = 2023

input_data = pd.DataFrame({'year': [year_input], 'id': [station_id]})
input_encoded = pd.get_dummies(input_data, columns=['id'])

# Align with training feature columns
missing_cols = set(X_encoded.columns) - set(input_encoded.columns)
for col in missing_cols:
    input_encoded[col] = 0
input_encoded = input_encoded[X_encoded.columns]  # reorder columns

# Predict pollutants
predicted_pollutants = model.predict(input_encoded)[0]

print(f"\nPredicted pollutant levels for station '{station_id}' in {year_input}:")
for p, val in zip(pollutants, predicted_pollutants):
    print(f"  {p}: {val:.2f}")
# Out:
# Predicted pollutant levels for station '19' in 2023:
#   O2: 1.99
#   NO3: 6.35
#   NO2: 0.20
#   SO4: 44.44
#   PO4: 6.48
#   CL: 62.65

# %%
# Saving the Model
import joblib
joblib.dump(model, 'pollution_model.pkl')
joblib.dump(X_encoded.columns.tolist(), "model_columns.pkl")
print('Model and cols structure are saved!')
# Out:
# Model and cols structure are saved!

# %% [markdown]
# ### XGBoost Model

# %%
# Doing the Model Training using MultiOutputRegressor with XGBoost
from xgboost import XGBRegressor

# %%
# Training the model with XGBoost model
model = MultiOutputRegressor(XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
# ...

# %%
# Predict on test set
y_pred = model.predict(X_test)

# %%
# Evaluate the model
print("Model Performance:")
for i, col in enumerate(pollutants):
    print(f"{col}: MSE = {mean_squared_error(y_test.iloc[:, i], y_pred[:, i]):.3f}, R² = {r2_score(y_test.iloc[:, i], y_pred[:, i]):.3f}")
# Out:
# Model Performance:
# O2: MSE = 20.610, R² = 0.057
# NO3: MSE = 32.975, R² = 0.121
# NO2: MSE = 0.292, R² = -1.190
# SO4: MSE = 2676.114, R² = 0.347
# PO4: MSE = 0.371, R² = 0.347
# CL: MSE = 107534.287, R² = 0.186

# %%
# Prediction by taking an Example like taking specific station and year.
station_id = 12
year_input = 2024
input_df = pd.DataFrame({'year': [year_input], 'id': [station_id]})
input_encoded = pd.get_dummies(input_df, columns=['id'])
input_encoded = input_encoded.reindex(columns=X_encoded.columns, fill_value=0)

prediction = model.predict(input_encoded)
print("\nPredicted pollutant values for station 22 in 2025:")
print(dict(zip(pollutants, prediction[0])))
# Out:
# Predicted pollutant values for station 22 in 2025:
# {'O2': np.float32(11.101172), 'NO3': np.float32(4.0558186), 'NO2': np.float32(0.41598043), 'SO4': np.float32(47.401867), 'PO4': np.float32(0.20833384), 'CL': np.float32(83.90263)}

# %%
# Save the model and column structure
joblib.dump(model, 'xgb_pollution_model.pkl')
joblib.dump(X_encoded.columns.tolist(), 'xgb_model_columns.pkl')
# Out:
# ['xgb_model_columns.pkl']
